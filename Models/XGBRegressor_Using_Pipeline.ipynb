# %% [markdown]
# # XGBRegressor Pipeline

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import os
import pickle
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV, KFold, train_test_split, cross_val_score

# %% [markdown]
# Different brands and models were concatenated to one dataframe

# %%
# Read and concatenate all CSV's

path = r'D:\Data_Analytics\Project 3\Data'
all_files = glob.glob(path + "/*.csv")

li = []
brands = ["Audi","Skoda","BMW","Volkswagen","Toyota","Mercedes Benz","Ford","Hyundi"]

for filename, brand in zip(all_files, brands):
    df = pd.read_csv(filename, index_col=None, header=0)
    df["make"] = brand
    li.append(df)
    
frame = pd.concat(li, axis=0, ignore_index=True)
frame
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0           A1  2017  12500       Manual    15735   Petrol  150  55.4
# 1           A6  2016  16500    Automatic    36203   Diesel   20  64.2
# 2           A1  2016  11000       Manual    29946   Petrol   30  55.4
# 3           A4  2017  16800    Automatic    25952   Diesel  145  67.3
# 4           A3  2019  17300       Manual     1998   Petrol  145  49.6
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 85550      I30  2016   8680       Manual    25906   Diesel    0  78.4
# 85551      I40  2015   7830       Manual    59508   Diesel   30  65.7
# 85552      I10  2017   6830       Manual    13810   Petrol   20  60.1
# 85553   Tucson  2018  13994       Manual    23313   Petrol  145  44.8
# 85554   Tucson  2016  15999    Automatic    11472   Diesel  125  57.6
#
#        engineSize    make
# 0             1.4    Audi
# 1             2.0    Audi
# 2             1.4    Audi
# 3             2.0    Audi
# 4             1.0    Audi
# ...           ...     ...
# 85550         1.6  Hyundi
# 85551         1.7  Hyundi
# 85552         1.0  Hyundi
# 85553         1.6  Hyundi
# 85554         1.7  Hyundi
#
# [85555 rows x 10 columns]

# %%
# remove unwanted feature
frame =frame.drop("tax", axis=1)

# %%
frame_filtered = frame.loc[frame['year'] != 2060]
frame_filtered
# Out:
#          model  year  price transmission  mileage fuelType   mpg  engineSize  \
# 0           A1  2017  12500       Manual    15735   Petrol  55.4         1.4
# 1           A6  2016  16500    Automatic    36203   Diesel  64.2         2.0
# 2           A1  2016  11000       Manual    29946   Petrol  55.4         1.4
# 3           A4  2017  16800    Automatic    25952   Diesel  67.3         2.0
# 4           A3  2019  17300       Manual     1998   Petrol  49.6         1.0
# ...        ...   ...    ...          ...      ...      ...   ...         ...
# 85550      I30  2016   8680       Manual    25906   Diesel  78.4         1.6
# 85551      I40  2015   7830       Manual    59508   Diesel  65.7         1.7
# 85552      I10  2017   6830       Manual    13810   Petrol  60.1         1.0
# 85553   Tucson  2018  13994       Manual    23313   Petrol  44.8         1.6
# 85554   Tucson  2016  15999    Automatic    11472   Diesel  57.6         1.7
#
#          make
# 0        Audi
# 1        Audi
# 2        Audi
# 3        Audi
# 4        Audi
# ...       ...
# 85550  Hyundi
# 85551  Hyundi
# 85552  Hyundi
# 85553  Hyundi
# 85554  Hyundi
#
# [85554 rows x 9 columns]

# %% [markdown]
# # Pipeline

# %% [markdown]
# Categorical and Numeric Features were preprocessed separately

# %%
# define numeric features

num_features = ['year','mileage','mpg','engineSize']

# Pipeline steps to transform numeric features
num_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant')),
                                      ('scaler', StandardScaler())])

# %%
# define categorical features

cat_features = ['model','transmission','fuelType','make']

# Pipeline to transform (encode) categorical features

cat_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
# Use "ColumnTransformer" to join both categorical and numeric pipelines
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_features),
        ('cat', cat_transformer, cat_features)])

# %% [markdown]
# # Adriana's Step

# %%
# transformer = Pipeline(steps=[('preprocessor', preprocessor)])

# %%
# Define X, y

# X = frame_filtered.drop('price', axis = 1)
# y = frame_filtered['price']

# %%
# transformed_axis = transformer.fit(X,y)
# transformed_axis

# %%
# pkl_filename = "axis_transformed.pkl"
# with open(pkl_filename, 'wb') as file:
#     pickle.dump(transformed_axis, file)

# %% [markdown]
# # Continue ...

# %%
# define Lasso model
regressor_model = XGBRegressor()

# %%
# Create a pipeline that execute "preprocessor" and the Lasso model
regression = Pipeline(steps=[('preprocessor', preprocessor),
                      ('regressor',regressor_model )])

# %%
# Define X, y

X = frame_filtered.drop('price', axis = 1)
y = frame_filtered['price']

# %%
# Split X,y into train and test

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
X_train
# Out:
#            model  year transmission  mileage fuelType   mpg  engineSize  \
# 40184         Up  2013       Manual    30442   Petrol  60.1         1.0
# 22786   1 Series  2016    Semi-Auto    37753   Diesel  67.3         2.0
# 47489       Aygo  2018    Semi-Auto     8751   Petrol  67.3         1.0
# 34666       Polo  2019       Manual       11   Diesel  57.7         1.6
# 8148          A6  2010       Manual    42000   Diesel  49.6         2.0
# ...          ...   ...          ...      ...      ...   ...         ...
# 6265          A3  2019    Semi-Auto     2308   Petrol  34.5         2.0
# 54886    C Class  2019    Semi-Auto    15275   Petrol  45.6         1.5
# 76820     Fiesta  2015       Manual    18000   Petrol  47.9         1.6
# 860           A1  2020       Manual      556   Petrol  47.9         1.0
# 15795     Superb  2018    Semi-Auto     4804   Diesel  61.4         2.0
#
#                 make
# 40184     Volkswagen
# 22786            BMW
# 47489         Toyota
# 34666     Volkswagen
# 8148            Audi
# ...              ...
# 6265            Audi
# 54886  Mercedes Benz
# 76820           Ford
# 860             Audi
# 15795          Skoda
#
# [64165 rows x 8 columns]

# %%
# search hyperparameters

regression.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'preprocessor', 'regressor', 'preprocessor__n_jobs', 'preprocessor__remainder', 'preprocessor__sparse_threshold', 'preprocessor__transformer_weights', 'preprocessor__transformers', 'preprocessor__verbose', 'preprocessor__num', 'preprocessor__cat', 'preprocessor__num__memory', 'preprocessor__num__steps', 'preprocessor__num__verbose', 'preprocessor__num__imputer', 'preprocessor__num__scaler', 'preprocessor__num__imputer__add_indicator', 'preprocessor__num__imputer__copy', 'preprocessor__num__imputer__fill_value', 'preprocessor__num__imputer__missing_values', 'preprocessor__num__imputer__strategy', 'preprocessor__num__imputer__verbose', 'preprocessor__num__scaler__copy', 'preprocessor__num__scaler__with_mean', 'preprocessor__num__scaler__with_std', 'preprocessor__cat__memory', 'preprocessor__cat__steps', 'preprocessor__cat__verbose', 'preprocessor__cat__imputer', 'preprocessor__cat__onehot', 'preprocessor__cat__imputer__add_indicator', 'preprocessor__cat__imputer__copy', 'preprocessor__cat__imputer__fill_value', 'preprocessor__cat__imputer__missing_values', 'preprocessor__cat__imputer__strategy', 'preprocessor__cat__imputer__verbose', 'preprocessor__cat__onehot__categories', 'preprocessor__cat__onehot__drop', 'preprocessor__cat__onehot__dtype', 'preprocessor__cat__onehot__handle_unknown', 'preprocessor__cat__onehot__sparse', 'regressor__objective', 'regressor__base_score', 'regressor__booster', 'regressor__colsample_bylevel', 'regressor__colsample_bynode', 'regressor__colsample_bytree', 'regressor__gamma', 'regressor__gpu_id', 'regressor__importance_type', 'regressor__interaction_constraints', 'regressor__learning_rate', 'regressor__max_delta_step', 'regressor__max_depth', 'regressor__min_child_weight', 'regressor__missing', 'regressor__monotone_constraints', 'regressor__n_estimators', 'regressor__n_jobs', 'regressor__num_parallel_tree', 'regressor__random_state', 'regressor__reg_alpha', 'regressor__reg_lambda', 'regressor__scale_pos_weight', 'regressor__subsample', 'regressor__tree_method', 'regressor__validate_parameters', 'regressor__verbosity'])

# %%
n_estimators = [int(x) for x in np.linspace(start = 20, stop = 40, num = 5)]
max_depth = [int(x) for x in np.linspace(2, 18, num = 10)]
max_depth.append(None)
gbm_param_grid = {
    'regressor__colsample_bytree': [0.3, 0.7],
    'regressor__n_estimators': n_estimators,
    'regressor__max_depth': max_depth
}

# %%
# apply GridSearchCV for tuning
search = GridSearchCV(estimator = regression, param_grid= gbm_param_grid, cv=4, verbose = 3)

# %%
# fit the model
search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 110 candidates, totalling 440 fits
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20, score=0.832, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20, score=0.832, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.0s remaining:    0.0s
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20, score=0.833, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=20, score=0.842, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25, score=0.844, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25, score=0.845, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25, score=0.846, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=25, score=0.851, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30, score=0.857, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30, score=0.854, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30, score=0.855, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=30, score=0.861, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35, score=0.866, total=   1.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35, score=0.865, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35, score=0.860, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=35, score=0.868, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40, score=0.872, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40, score=0.871, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40, score=0.866, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=2, regressor__n_estimators=40, score=0.872, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20, score=0.870, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20, score=0.869, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20, score=0.872, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=20, score=0.873, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25, score=0.879, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25, score=0.880, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25, score=0.881, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=25, score=0.882, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30, score=0.889, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30, score=0.890, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30, score=0.889, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=30, score=0.889, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35, score=0.895, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35, score=0.895, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35, score=0.895, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=35, score=0.894, total=   1.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40, score=0.898, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40, score=0.898, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40, score=0.899, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=3, regressor__n_estimators=40, score=0.898, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20, score=0.915, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20, score=0.914, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20, score=0.915, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=20, score=0.915, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25, score=0.920, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25, score=0.919, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25, score=0.920, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=25, score=0.920, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30, score=0.925, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30, score=0.923, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30, score=0.926, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=30, score=0.926, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35, score=0.929, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35, score=0.928, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35, score=0.929, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=35, score=0.929, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40, score=0.930, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40, score=0.930, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40, score=0.931, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=5, regressor__n_estimators=40, score=0.931, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20, score=0.933, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20, score=0.933, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20, score=0.936, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=20, score=0.935, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25, score=0.937, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25, score=0.936, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25, score=0.939, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=25, score=0.938, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30, score=0.941, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30, score=0.939, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30, score=0.942, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=30, score=0.941, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35, score=0.943, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35, score=0.942, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35, score=0.945, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=35, score=0.944, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40, score=0.944, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40, score=0.943, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40, score=0.946, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=7, regressor__n_estimators=40, score=0.945, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20, score=0.941, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20, score=0.941, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20, score=0.946, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=20, score=0.945, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25, score=0.943, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25, score=0.943, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25, score=0.948, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=25, score=0.947, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30, score=0.947, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30, score=0.946, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30, score=0.951, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=30, score=0.950, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35, score=0.949, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35, score=0.950, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35, score=0.953, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=35, score=0.952, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40, score=0.950, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40, score=0.950, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40, score=0.954, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=9, regressor__n_estimators=40, score=0.952, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20, score=0.944, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20, score=0.944, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20, score=0.948, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=20, score=0.947, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25, score=0.947, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25, score=0.945, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25, score=0.950, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=25, score=0.949, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30, score=0.950, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30, score=0.948, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30, score=0.954, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=30, score=0.952, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35, score=0.953, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35, score=0.951, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35, score=0.956, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=35, score=0.954, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40, score=0.954, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40, score=0.952, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40, score=0.956, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=10, regressor__n_estimators=40, score=0.954, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20, score=0.949, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20, score=0.947, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20, score=0.951, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=20, score=0.951, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25, score=0.951, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25, score=0.948, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25, score=0.953, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=25, score=0.952, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30, score=0.954, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30, score=0.951, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30, score=0.957, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=30, score=0.955, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35, score=0.957, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35, score=0.954, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35, score=0.958, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=35, score=0.957, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40, score=0.957, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40, score=0.954, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40, score=0.959, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=12, regressor__n_estimators=40, score=0.957, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20, score=0.952, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20, score=0.949, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20, score=0.954, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=20, score=0.952, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25, score=0.953, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25, score=0.950, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25, score=0.955, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=25, score=0.953, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30, score=0.956, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30, score=0.952, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30, score=0.958, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=30, score=0.956, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35, score=0.958, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35, score=0.955, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35, score=0.960, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=35, score=0.958, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40, score=0.958, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40, score=0.955, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40, score=0.960, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=14, regressor__n_estimators=40, score=0.958, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20, score=0.953, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20, score=0.951, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20, score=0.954, total=   0.9s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=20, score=0.953, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25, score=0.954, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25, score=0.952, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25, score=0.955, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=25, score=0.954, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30, score=0.957, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30, score=0.954, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30, score=0.958, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=30, score=0.957, total=   1.3s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35, score=0.959, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35, score=0.956, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35, score=0.960, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=35, score=0.958, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40, score=0.959, total=   1.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40, score=0.956, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40, score=0.960, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=16, regressor__n_estimators=40, score=0.959, total=   1.5s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20, score=0.953, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20, score=0.951, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20, score=0.954, total=   1.1s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=20, score=0.954, total=   1.0s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25, score=0.954, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25, score=0.953, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25, score=0.956, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=25, score=0.955, total=   1.2s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30, score=0.957, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30, score=0.955, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30, score=0.958, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=30, score=0.957, total=   1.4s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35, score=0.958, total=   1.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35, score=0.956, total=   1.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35, score=0.960, total=   1.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=35, score=0.959, total=   1.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40, score=0.959, total=   1.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40, score=0.957, total=   1.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40, score=0.960, total=   1.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=18, regressor__n_estimators=40, score=0.959, total=   1.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20, score=0.927, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20, score=0.925, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20, score=0.926, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=20, score=0.927, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25, score=0.931, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25, score=0.928, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25, score=0.931, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=25, score=0.931, total=   0.6s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30, score=0.936, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30, score=0.932, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30, score=0.935, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=30, score=0.935, total=   0.7s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35, score=0.938, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35, score=0.936, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35, score=0.938, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=35, score=0.938, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40, score=0.939, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40, score=0.938, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40, score=0.939, total=   0.8s
# [CV] regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.3, regressor__max_depth=None, regressor__n_estimators=40, score=0.939, total=   0.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20, score=0.839, total=   0.5s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20, score=0.843, total=   0.5s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20, score=0.837, total=   0.5s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=20, score=0.846, total=   0.5s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=25, score=0.848, total=   0.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=25, score=0.856, total=   0.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=25, score=0.850, total=   0.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=2, regressor__n_estimators=25
# ...
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=35, score=0.960, total=   2.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40, score=0.959, total=   2.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40, score=0.960, total=   2.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40, score=0.965, total=   2.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=14, regressor__n_estimators=40, score=0.960, total=   2.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20, score=0.959, total=   1.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20, score=0.959, total=   1.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20, score=0.965, total=   1.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=20, score=0.960, total=   1.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25, score=0.959, total=   2.0s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25, score=0.959, total=   1.9s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25, score=0.965, total=   1.9s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=25, score=0.960, total=   2.0s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30, score=0.960, total=   2.3s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30, score=0.959, total=   2.3s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30, score=0.965, total=   2.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=30, score=0.960, total=   2.3s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35, score=0.960, total=   2.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35, score=0.959, total=   2.5s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35, score=0.965, total=   2.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=35, score=0.960, total=   2.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40, score=0.960, total=   2.7s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40, score=0.959, total=   2.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40, score=0.965, total=   2.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=16, regressor__n_estimators=40, score=0.960, total=   2.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20, score=0.959, total=   1.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20, score=0.960, total=   1.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20, score=0.965, total=   1.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=20, score=0.960, total=   1.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25, score=0.959, total=   2.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25, score=0.960, total=   2.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25, score=0.965, total=   2.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=25, score=0.960, total=   2.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30, score=0.959, total=   2.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30, score=0.960, total=   2.5s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30, score=0.965, total=   2.7s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=30, score=0.959, total=   2.6s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35, score=0.959, total=   2.7s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35, score=0.960, total=   2.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35, score=0.965, total=   2.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=35, score=0.960, total=   2.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40, score=0.959, total=   3.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40, score=0.960, total=   3.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40, score=0.965, total=   3.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=18, regressor__n_estimators=40, score=0.959, total=   3.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20, score=0.932, total=   0.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20, score=0.932, total=   0.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20, score=0.933, total=   0.9s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=20, score=0.932, total=   0.8s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25, score=0.936, total=   1.0s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25, score=0.936, total=   1.0s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25, score=0.937, total=   1.0s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=25, score=0.935, total=   1.0s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30, score=0.939, total=   1.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30, score=0.937, total=   1.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30, score=0.940, total=   1.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=30, score=0.939, total=   1.1s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35, score=0.941, total=   1.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35, score=0.939, total=   1.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35, score=0.942, total=   1.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=35, score=0.940, total=   1.2s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40, score=0.942, total=   1.3s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40, score=0.941, total=   1.4s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40, score=0.944, total=   1.3s
# [CV] regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40
# [CV]  regressor__colsample_bytree=0.7, regressor__max_depth=None, regressor__n_estimators=40, score=0.942, total=   1.3s
# [Parallel(n_jobs=1)]: Done 440 out of 440 | elapsed:  9.1min finished
# GridSearchCV(cv=4, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('preprocessor',
#                                         ColumnTransformer(n_jobs=None,
#                                                           remainder='drop',
#                                                           sparse_threshold=0.3,
#                                                           transformer_weights=None,
#                                                           transformers=[('num',
#                                                                          Pipeline(memory=None,
#                                                                                   steps=[('imputer',
#                                                                                           SimpleImputer(add_indicator=False,
#                                                                                                         copy=True,
#                                                                                                         fill_value=None,
#                                                                                                         missing_values=nan,
#                                                                                                         strategy='constant',
#                                                                                                         verbose=0)...
#                                                      subsample=None,
#                                                      tree_method=None,
#                                                      validate_parameters=None,
#                                                      verbosity=None))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'regressor__colsample_bytree': [0.3, 0.7],
#                          'regressor__max_depth': [2, 3, 5, 7, 9, 10, 12, 14, 16,
#                                                   18, None],
#                          'regressor__n_estimators': [20, 25, 30, 35, 40]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# Print the best parameters and lowest RMSE
print("Best parameters found: ", search.best_params_)
print("Best Score found: ", np.sqrt(np.abs(search.best_score_)))
# Out:
# Best parameters found:  {'regressor__colsample_bytree': 0.7, 'regressor__max_depth': 16, 'regressor__n_estimators': 40}
# Best Score found:  0.980391237590368

# %%
# check test accuracy
print('Test Acc: %.3f' % search.score(X_test, y_test))
# Out:
# Test Acc: 0.958

# %%
# check best score
print('Test Acc: %.3f' % search.best_score_)
# Out:
# Test Acc: 0.961

# %%
# define model "best params"
search.best_params_
# Out:
# {'regressor__colsample_bytree': 0.7,
#  'regressor__max_depth': 16,
#  'regressor__n_estimators': 40}

# %% [markdown]
# # Saving the Model

# %%
pkl_filename = "regression_XGB_model.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(search, file)

# %% [markdown]
# # Real Predictions

# %%
values = ['Yaris',2015,'Automatic', 36021,'Hybrid',78,1.5,'Toyota']

# %%
features = [np.array(values)]

# %%
df = pd.DataFrame(features,columns=['model','year','transmission','mileage','fuelType','mpg','engineSize','make'])
df
# Out:
#    model  year transmission mileage fuelType mpg engineSize    make
# 0  Yaris  2015    Automatic   36021   Hybrid  78        1.5  Toyota

# %%
pkl_filename = "regression_XGB_model.pkl"
with open(pkl_filename, 'rb') as file:
    model_linear = pickle.load(file)

# %%
model_linear.predict(df)
# Out:
# array([12289.301], dtype=float32)
